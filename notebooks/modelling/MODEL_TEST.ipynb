# %%
pip install tensorflow_recommenders
# Out:
# Collecting tensorflow_recommenders
#   Downloading tensorflow_recommenders-0.7.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow_recommenders) (1.4.0)
# Requirement already satisfied: tensorflow>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.9.0->tensorflow_recommenders) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.9.0->tensorflow_recommenders) (3.2.2)
# Installing collected packages: tensorflow_recommenders
# Successfully installed tensorflow_recommenders-0.7.3

# %%
import tensorflow as tf
import tensorflow_recommenders as tfrs
import pandas as pd
import numpy as np
import pickle

# Example data structure with titles and ingredient groups
df = pd.read_csv('sabi_kali_with_ids.csv')
ingredients_df = pd.read_csv('UniqueIngredients.csv')

# Function to calculate daily calorie needs based on height and weight
def calculate_calories(height_cm, weight_kg, age, gender):
    if gender == 'male':
        bmr = 66 + (13.7 * weight_kg) + (5 * height_cm) - (6.8 * age)
    else:
        bmr = 655 + (9.6 * weight_kg) + (1.8 * height_cm) - (4.7 * age)
    daily_calories = bmr * 1.2  # Assuming sedentary activity level
    return daily_calories

# Convert DataFrame to TensorFlow Dataset
tf_dataset = tf.data.Dataset.from_tensor_slices({
    'recipe_id': df['recipe_id'].values,
    'title': df['Title'].values,
    'ingredients': df['Simplified Ingredients'].values,
    'calories': df['Calories'].values,
    'ingredient_groups': df['Ingredient Groups'].values
})

# Shuffle and batch the dataset
tf_dataset = tf_dataset.shuffle(10000).batch(128).cache()

class RecipeModel(tfrs.Model):

    def __init__(self, ingredient_vocab, embedding_dimension=32):
        super().__init__()

        # Define recipe embedding layers
        self.ingredient_lookup = tf.keras.layers.StringLookup(vocabulary=ingredient_vocab, mask_token=None)
        self.ingredient_embedding = tf.keras.layers.Embedding(len(ingredient_vocab) + 1, embedding_dimension)

        # Define the task
        self.task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=tf.data.Dataset.from_tensor_slices(ingredient_vocab).batch(128).map(self.compute_candidate_embeddings)
            )
        )

    def compute_candidate_embeddings(self, ingredients):
        ingredients_split = tf.strings.split(ingredients, sep=', ')
        ingredient_ids = self.ingredient_lookup(ingredients_split)
        ingredient_embeddings = self.ingredient_embedding(ingredient_ids)
        recipe_embeddings = tf.reduce_mean(ingredient_embeddings, axis=1)
        return recipe_embeddings

    def compute_query_embeddings(self, ingredients):
        ingredients_split = tf.strings.split(ingredients, sep=', ')
        ingredient_ids = self.ingredient_lookup(ingredients_split)
        ingredient_embeddings = self.ingredient_embedding(ingredient_ids)
        recipe_embeddings = tf.reduce_mean(ingredient_embeddings, axis=1)
        return recipe_embeddings

    def call(self, features):
        # Forward pass to compute embeddings
        if isinstance(features, dict):
            return self.compute_query_embeddings(features['ingredients'])
        else:
            return self.compute_query_embeddings(features)

    def compute_loss(self, features, training=False):
        query_embeddings = self(features)
        return self.task(query_embeddings=query_embeddings, candidate_embeddings=query_embeddings)

def get_user_input():
    # Get height and validate
    while True:
        try:
            height_cm = float(input("Enter your height in cm: "))
            if height_cm <= 0:
                raise ValueError("Height must be a positive number.")
            break
        except ValueError as e:
            print(f"Invalid input: {e}")

    # Get weight and validate
    while True:
        try:
            weight_kg = float(input("Enter your weight in kg: "))
            if weight_kg <= 0:
                raise ValueError("Weight must be a positive number.")
            break
        except ValueError as e:
            print(f"Invalid input: {e}")

    # Get age and validate
    while True:
        try:
            age = int(input("Enter your age: "))
            if age <= 0:
                raise ValueError("Age must be a positive number.")
            break
        except ValueError as e:
            print(f"Invalid input: {e}")

    # Get gender and validate
    while True:
        gender = input("Enter your gender (male/female): ").strip().lower()
        if gender in ['male', 'female']:
            break
        else:
            print("Invalid input: Gender must be 'male' or 'female'.")

    # Get activity level and validate
    activity_levels = {
        'sedentary': 1.2,
        'lightly active': 1.375,
        'moderately active': 1.55,
        'very active': 1.725,
        'extra active': 1.9
    }

    print("Select your activity level from the following options:")
    for level in activity_levels:
        print(f"- {level}")

    while True:
        activity_level = input("Enter your activity level: ").strip().lower()
        if activity_level in activity_levels:
            activity_factor = activity_levels[activity_level]
            break
        else:
            print("Invalid input: Please select a valid activity level.")

    # Get the list of unique ingredients
    unique_ingredients = ingredients_df['Ingredient'].dropna().str.lower().tolist()

    # Get allergens and dietary preferences from the user
    while True:
        user_allergens = input("Enter allergens separated by commas (e.g., nuts, gluten): ").split(',')
        user_allergens = [allergen.strip().lower() for allergen in user_allergens]  # Remove leading/trailing spaces and convert to lowercase

        # Check if the allergens are in the unique ingredients list
        invalid_allergens = [allergen for allergen in user_allergens if allergen not in unique_ingredients]

        if invalid_allergens:
            print(f"The following allergens are not recognized: {', '.join(invalid_allergens)}")
            print("Please enter recognized allergens.")
        else:
            print("All allergens are recognized.")
            break

    # Join allergens into a single string
    user_allergens = ', '.join(user_allergens)

    dietary_preferences = input("Enter dietary preferences separated by commas (e.g., vegan, vegetarian): ").split(',')
    dietary_preferences = [preference.strip() for preference in dietary_preferences]  # Remove leading/trailing spaces

    # Get ingredients user has
    while True:
        user_ingredients = input("Enter ingredients you have separated by commas (e.g., chicken, rice): ").split(',')
        user_ingredients = [ingredient.strip().lower() for ingredient in user_ingredients]  # Remove leading/trailing spaces and convert to lowercase

        # Check if the ingredients are in the unique ingredients list
        invalid_ingredients = [ingredient for ingredient in user_ingredients if ingredient not in unique_ingredients]

        if invalid_ingredients:
            print(f"The following ingredients are not recognized: {', '.join(invalid_ingredients)}")
            print("Please enter recognized ingredients.")
        else:
            print("All ingredients are recognized.")
            break

    # Join ingredients into a single string
    user_ingredients = ', '.join(user_ingredients)

    return height_cm, weight_kg, age, gender, activity_factor, user_allergens, dietary_preferences, user_ingredients

height_cm, weight_kg, age, gender, activity_factor, user_allergens, dietary_preferences, user_ingredients = get_user_input()

# Create vocabulary of ingredients
ingredient_vocab = sorted(set(', '.join(df['Simplified Ingredients']).split(', ')))

# Instantiate the model
model = RecipeModel(ingredient_vocab)
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

# Train the model
model.fit(tf_dataset, epochs=100)

# Save the model configuration and weights separately
model_config = model.get_config()
model_weights = model.get_weights()

# Save the configuration and weights to disk
with open('recipe_model_config.pkl', 'wb') as f:
    pickle.dump(model_config, f)
with open('recipe_model_weights.pkl', 'wb') as f:
    pickle.dump(model_weights, f)

# Load the configuration and weights from disk
with open('recipe_model_config.pkl', 'rb') as f:
    loaded_config = pickle.load(f)
with open('recipe_model_weights.pkl', 'rb') as f:
    loaded_weights = pickle.load(f)

# Reconstruct the model
reconstructed_model = RecipeModel(ingredient_vocab)
sample_input = {'ingredients': tf.constant(["beef"])}
reconstructed_model(sample_input)
reconstructed_model.set_weights(loaded_weights)
reconstructed_model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.5))

# Use BruteForce layer to find top recommendations
index = tfrs.layers.factorized_top_k.BruteForce(reconstructed_model)

# Prepare candidates dataset
candidate_embeddings = tf.data.Dataset.from_tensor_slices({
    'recipe_id': df['recipe_id'].values,
    'title': df['Title'].values,
    'ingredients': df['Simplified Ingredients'].values
}).batch(128).map(lambda x: (x['recipe_id'], reconstructed_model.compute_candidate_embeddings(x['ingredients'])))

# Set the index from the candidate embeddings
index.index_from_dataset(candidate_embeddings)

# Get recommendations
example_recipe = [user_ingredients]
user_calories = calculate_calories(height_cm, weight_kg, age, gender) * activity_factor
min_calories = user_calories * 0.9 / 4
max_calories = user_calories * 1.1 / 4
excluded_ingredients = [user_allergens]

# Filter
filtered_df = df[(df['Calories'] >= min_calories) & (df['Calories'] <= max_calories)]

def contains_excluded_ingredient(ingredients, excluded_ingredients):
    ingredients_set = set(ingredients.split(', '))
    excluded_set = set(excluded_ingredients)
    return not ingredients_set.isdisjoint(excluded_set)

filtered_df = filtered_df[~filtered_df['Simplified Ingredients'].apply(lambda x: contains_excluded_ingredient(x, excluded_ingredients))]


filtered_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'recipe_id': filtered_df['recipe_id'].values,
    'title': filtered_df['Title'].values,
    'ingredients': filtered_df['Simplified Ingredients'].values,
    'ingredient_groups': filtered_df['Ingredient Groups'].values
}).batch(128).map(lambda x: (x['recipe_id'], reconstructed_model.compute_candidate_embeddings(x['ingredients'])))

index.index_from_dataset(filtered_tf_dataset)

example_recipe_tensor = tf.constant(example_recipe)
scores, top_k = index(example_recipe_tensor, k=4)

print("Top recommendations:")
for i in range(len(top_k[0])):
    recipe_id = top_k[0][i].numpy()
    print(f"Recommended recipe ID: {recipe_id}")
    matching_recipes = filtered_df[filtered_df['recipe_id'] == recipe_id]

    if not matching_recipes.empty:
        title = matching_recipes.Title.values[0]
        ingredients = matching_recipes['Simplified Ingredients'].values[0]
        ingredient_groups = matching_recipes['Ingredient Groups'].values[0]
        calories = matching_recipes['Calories'].values[0]
        print(f"Title: {title}\nIngredients: {ingredients}\nIngredient Groups: {ingredient_groups}\Calories: {calories}\n")
    else:
        print(f"Tidak ada resep yang cocok untuk ID resep: {recipe_id}\n")
# Out:
# Enter your height in cm: 178
# Enter your weight in kg: 78
# Enter your age: 21
# Enter your gender (male/female): male
# Select your activity level from the following options:
# - sedentary
# - lightly active
# - moderately active
# - very active
# - extra active
# Enter your activity level: sedentary
# Enter allergens separated by commas (e.g., nuts, gluten): beef
# All allergens are recognized.
# Enter dietary preferences separated by commas (e.g., vegan, vegetarian):
# Enter ingredients you have separated by commas (e.g., chicken, rice): milk
# All ingredients are recognized.
# Epoch 1/100
# 11/11 [==============================] - 3s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0958 - factorized_top_k/top_10_categorical_accuracy: 0.4664 - factorized_top_k/top_50_categorical_accuracy: 0.9359 - factorized_top_k/top_100_categorical_accuracy: 0.9807 - loss: 505.0895 - regularization_loss: 0.0000e+00 - total_loss: 505.0895
# Epoch 2/100
# 11/11 [==============================] - 2s 151ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0015 - factorized_top_k/top_5_categorical_accuracy: 0.0819 - factorized_top_k/top_10_categorical_accuracy: 0.4981 - factorized_top_k/top_50_categorical_accuracy: 0.9884 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 440.3375 - regularization_loss: 0.0000e+00 - total_loss: 440.3375
# Epoch 3/100
# 11/11 [==============================] - 3s 245ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0015 - factorized_top_k/top_5_categorical_accuracy: 0.1668 - factorized_top_k/top_10_categorical_accuracy: 0.6170 - factorized_top_k/top_50_categorical_accuracy: 0.9892 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 397.3411 - regularization_loss: 0.0000e+00 - total_loss: 397.3411
# Epoch 4/100
# 11/11 [==============================] - 2s 154ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0015 - factorized_top_k/top_5_categorical_accuracy: 0.2224 - factorized_top_k/top_10_categorical_accuracy: 0.6664 - factorized_top_k/top_50_categorical_accuracy: 0.9900 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 360.4160 - regularization_loss: 0.0000e+00 - total_loss: 360.4160
# Epoch 5/100
# 11/11 [==============================] - 2s 150ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0039 - factorized_top_k/top_5_categorical_accuracy: 0.2687 - factorized_top_k/top_10_categorical_accuracy: 0.6942 - factorized_top_k/top_50_categorical_accuracy: 0.9931 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 327.2487 - regularization_loss: 0.0000e+00 - total_loss: 327.2487
# Epoch 6/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3058 - factorized_top_k/top_10_categorical_accuracy: 0.7073 - factorized_top_k/top_50_categorical_accuracy: 0.9946 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 297.5219 - regularization_loss: 0.0000e+00 - total_loss: 297.5219
# Epoch 7/100
# 11/11 [==============================] - 2s 194ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3328 - factorized_top_k/top_10_categorical_accuracy: 0.7251 - factorized_top_k/top_50_categorical_accuracy: 0.9938 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 270.9594 - regularization_loss: 0.0000e+00 - total_loss: 270.9594
# Epoch 8/100
# 11/11 [==============================] - 2s 205ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3583 - factorized_top_k/top_10_categorical_accuracy: 0.7514 - factorized_top_k/top_50_categorical_accuracy: 0.9961 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 247.3673 - regularization_loss: 0.0000e+00 - total_loss: 247.3673
# Epoch 9/100
# 11/11 [==============================] - 2s 152ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3714 - factorized_top_k/top_10_categorical_accuracy: 0.7629 - factorized_top_k/top_50_categorical_accuracy: 0.9969 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 226.4674 - regularization_loss: 0.0000e+00 - total_loss: 226.4674
# Epoch 10/100
# 11/11 [==============================] - 2s 152ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3938 - factorized_top_k/top_10_categorical_accuracy: 0.7714 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 207.9254 - regularization_loss: 0.0000e+00 - total_loss: 207.9254
# Epoch 11/100
# 11/11 [==============================] - 2s 156ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0046 - factorized_top_k/top_5_categorical_accuracy: 0.3923 - factorized_top_k/top_10_categorical_accuracy: 0.7753 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 191.4759 - regularization_loss: 0.0000e+00 - total_loss: 191.4759
# Epoch 12/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4039 - factorized_top_k/top_10_categorical_accuracy: 0.7792 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 176.8548 - regularization_loss: 0.0000e+00 - total_loss: 176.8548
# Epoch 13/100
# 11/11 [==============================] - 2s 158ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4100 - factorized_top_k/top_10_categorical_accuracy: 0.7822 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 163.7843 - regularization_loss: 0.0000e+00 - total_loss: 163.7843
# Epoch 14/100
# 11/11 [==============================] - 3s 250ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4100 - factorized_top_k/top_10_categorical_accuracy: 0.7938 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 152.0076 - regularization_loss: 0.0000e+00 - total_loss: 152.0076
# Epoch 15/100
# 11/11 [==============================] - 2s 158ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4178 - factorized_top_k/top_10_categorical_accuracy: 0.7969 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 141.3367 - regularization_loss: 0.0000e+00 - total_loss: 141.3367
# Epoch 16/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4239 - factorized_top_k/top_10_categorical_accuracy: 0.8046 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 131.6476 - regularization_loss: 0.0000e+00 - total_loss: 131.6476
# Epoch 17/100
# 11/11 [==============================] - 2s 158ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4270 - factorized_top_k/top_10_categorical_accuracy: 0.8069 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 122.8438 - regularization_loss: 0.0000e+00 - total_loss: 122.8438
# Epoch 18/100
# 11/11 [==============================] - 3s 240ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4340 - factorized_top_k/top_10_categorical_accuracy: 0.8046 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9977 - loss: 114.8399 - regularization_loss: 0.0000e+00 - total_loss: 114.8399
# Epoch 19/100
# 11/11 [==============================] - 2s 152ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4378 - factorized_top_k/top_10_categorical_accuracy: 0.8154 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 107.5621 - regularization_loss: 0.0000e+00 - total_loss: 107.5621
# Epoch 20/100
# 11/11 [==============================] - 2s 151ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4340 - factorized_top_k/top_10_categorical_accuracy: 0.8185 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 100.9441 - regularization_loss: 0.0000e+00 - total_loss: 100.9441
# Epoch 21/100
# 11/11 [==============================] - 2s 157ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0039 - factorized_top_k/top_5_categorical_accuracy: 0.4317 - factorized_top_k/top_10_categorical_accuracy: 0.8270 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 94.9216 - regularization_loss: 0.0000e+00 - total_loss: 94.9216
# Epoch 22/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0046 - factorized_top_k/top_5_categorical_accuracy: 0.4340 - factorized_top_k/top_10_categorical_accuracy: 0.8309 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 89.4323 - regularization_loss: 0.0000e+00 - total_loss: 89.4323
# Epoch 23/100
# 11/11 [==============================] - 2s 192ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4347 - factorized_top_k/top_10_categorical_accuracy: 0.8347 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 84.4168 - regularization_loss: 0.0000e+00 - total_loss: 84.4168
# Epoch 24/100
# 11/11 [==============================] - 2s 208ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4324 - factorized_top_k/top_10_categorical_accuracy: 0.8363 - factorized_top_k/top_50_categorical_accuracy: 0.9977 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 79.8220 - regularization_loss: 0.0000e+00 - total_loss: 79.8220
# Epoch 25/100
# 11/11 [==============================] - 2s 154ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4347 - factorized_top_k/top_10_categorical_accuracy: 0.8402 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9985 - loss: 75.6014 - regularization_loss: 0.0000e+00 - total_loss: 75.6014
# Epoch 26/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4332 - factorized_top_k/top_10_categorical_accuracy: 0.8417 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 71.7149 - regularization_loss: 0.0000e+00 - total_loss: 71.7149
# Epoch 27/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4255 - factorized_top_k/top_10_categorical_accuracy: 0.8463 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 68.1278 - regularization_loss: 0.0000e+00 - total_loss: 68.1278
# Epoch 28/100
# 11/11 [==============================] - 2s 152ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4232 - factorized_top_k/top_10_categorical_accuracy: 0.8440 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 64.8098 - regularization_loss: 0.0000e+00 - total_loss: 64.8098
# Epoch 29/100
# 11/11 [==============================] - 2s 164ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4247 - factorized_top_k/top_10_categorical_accuracy: 0.8440 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 61.7348 - regularization_loss: 0.0000e+00 - total_loss: 61.7348
# Epoch 30/100
# 11/11 [==============================] - 2s 208ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0039 - factorized_top_k/top_5_categorical_accuracy: 0.4201 - factorized_top_k/top_10_categorical_accuracy: 0.8425 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 58.8803 - regularization_loss: 0.0000e+00 - total_loss: 58.8803
# Epoch 31/100
# 11/11 [==============================] - 2s 152ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0039 - factorized_top_k/top_5_categorical_accuracy: 0.4193 - factorized_top_k/top_10_categorical_accuracy: 0.8463 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 56.2268 - regularization_loss: 0.0000e+00 - total_loss: 56.2268
# Epoch 32/100
# 11/11 [==============================] - 2s 153ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4232 - factorized_top_k/top_10_categorical_accuracy: 0.8486 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 53.7574 - regularization_loss: 0.0000e+00 - total_loss: 53.7574
# Epoch 33/100
# 11/11 [==============================] - 2s 154ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4208 - factorized_top_k/top_10_categorical_accuracy: 0.8541 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 51.4568 - regularization_loss: 0.0000e+00 - total_loss: 51.4568
# Epoch 34/100
# 11/11 [==============================] - 2s 154ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4193 - factorized_top_k/top_10_categorical_accuracy: 0.8571 - factorized_top_k/top_50_categorical_accuracy: 0.9985 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 49.3112 - regularization_loss: 0.0000e+00 - total_loss: 49.3112
# Epoch 35/100
# 11/11 [==============================] - 2s 228ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4154 - factorized_top_k/top_10_categorical_accuracy: 0.8595 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 47.3075 - regularization_loss: 0.0000e+00 - total_loss: 47.3075
# Epoch 36/100
# 11/11 [==============================] - 2s 210ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4100 - factorized_top_k/top_10_categorical_accuracy: 0.8610 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 45.4335 - regularization_loss: 0.0000e+00 - total_loss: 45.4335
# Epoch 37/100
# 11/11 [==============================] - 2s 200ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4077 - factorized_top_k/top_10_categorical_accuracy: 0.8641 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 43.6781 - regularization_loss: 0.0000e+00 - total_loss: 43.6781
# Epoch 38/100
# 11/11 [==============================] - 2s 160ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4085 - factorized_top_k/top_10_categorical_accuracy: 0.8664 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 42.0311 - regularization_loss: 0.0000e+00 - total_loss: 42.0311
# Epoch 39/100
# 11/11 [==============================] - 2s 159ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4131 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 40.4833 - regularization_loss: 0.0000e+00 - total_loss: 40.4833
# Epoch 40/100
# 11/11 [==============================] - 2s 160ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4131 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 39.0266 - regularization_loss: 0.0000e+00 - total_loss: 39.0266
# Epoch 41/100
# 11/11 [==============================] - 2s 224ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4085 - factorized_top_k/top_10_categorical_accuracy: 0.8710 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 37.6535 - regularization_loss: 0.0000e+00 - total_loss: 37.6535
# Epoch 42/100
# 11/11 [==============================] - 2s 195ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4116 - factorized_top_k/top_10_categorical_accuracy: 0.8703 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 36.3573 - regularization_loss: 0.0000e+00 - total_loss: 36.3573
# Epoch 43/100
# 11/11 [==============================] - 2s 156ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4069 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 35.1319 - regularization_loss: 0.0000e+00 - total_loss: 35.1319
# Epoch 44/100
# 11/11 [==============================] - 2s 158ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4077 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 33.9719 - regularization_loss: 0.0000e+00 - total_loss: 33.9719
# Epoch 45/100
# 11/11 [==============================] - 2s 158ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4069 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 32.8726 - regularization_loss: 0.0000e+00 - total_loss: 32.8726
# Epoch 46/100
# 11/11 [==============================] - 2s 189ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4015 - factorized_top_k/top_10_categorical_accuracy: 0.8703 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 31.8296 - regularization_loss: 0.0000e+00 - total_loss: 31.8296
# Epoch 47/100
# 11/11 [==============================] - 2s 214ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3969 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 30.8391 - regularization_loss: 0.0000e+00 - total_loss: 30.8391
# Epoch 48/100
# 11/11 [==============================] - 2s 159ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3946 - factorized_top_k/top_10_categorical_accuracy: 0.8749 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 29.8976 - regularization_loss: 0.0000e+00 - total_loss: 29.8976
# Epoch 49/100
# 11/11 [==============================] - 2s 162ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3946 - factorized_top_k/top_10_categorical_accuracy: 0.8741 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 29.0020 - regularization_loss: 0.0000e+00 - total_loss: 29.0020
# Epoch 50/100
# 11/11 [==============================] - 2s 161ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3954 - factorized_top_k/top_10_categorical_accuracy: 0.8741 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 28.1495 - regularization_loss: 0.0000e+00 - total_loss: 28.1495
# Epoch 51/100
# 11/11 [==============================] - 2s 160ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3954 - factorized_top_k/top_10_categorical_accuracy: 0.8764 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 27.3376 - regularization_loss: 0.0000e+00 - total_loss: 27.3376
# Epoch 52/100
# 11/11 [==============================] - 4s 338ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3954 - factorized_top_k/top_10_categorical_accuracy: 0.8780 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 0.9992 - loss: 26.5639 - regularization_loss: 0.0000e+00 - total_loss: 26.5639
# Epoch 53/100
# 11/11 [==============================] - 2s 163ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3961 - factorized_top_k/top_10_categorical_accuracy: 0.8764 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 25.8263 - regularization_loss: 0.0000e+00 - total_loss: 25.8263
# Epoch 54/100
# 11/11 [==============================] - 2s 167ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3977 - factorized_top_k/top_10_categorical_accuracy: 0.8788 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 25.1228 - regularization_loss: 0.0000e+00 - total_loss: 25.1228
# Epoch 55/100
# 11/11 [==============================] - 2s 160ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4000 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 24.4513 - regularization_loss: 0.0000e+00 - total_loss: 24.4513
# Epoch 56/100
# 11/11 [==============================] - 2s 168ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4000 - factorized_top_k/top_10_categorical_accuracy: 0.8726 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 23.8102 - regularization_loss: 0.0000e+00 - total_loss: 23.8102
# Epoch 57/100
# 11/11 [==============================] - 3s 266ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4000 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 23.1977 - regularization_loss: 0.0000e+00 - total_loss: 23.1977
# Epoch 58/100
# 11/11 [==============================] - 2s 172ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.4008 - factorized_top_k/top_10_categorical_accuracy: 0.8718 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 22.6120 - regularization_loss: 0.0000e+00 - total_loss: 22.6120
# Epoch 59/100
# 11/11 [==============================] - 2s 162ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3977 - factorized_top_k/top_10_categorical_accuracy: 0.8726 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 22.0517 - regularization_loss: 0.0000e+00 - total_loss: 22.0517
# Epoch 60/100
# 11/11 [==============================] - 2s 172ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3961 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 21.5152 - regularization_loss: 0.0000e+00 - total_loss: 21.5152
# Epoch 61/100
# 11/11 [==============================] - 2s 224ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3977 - factorized_top_k/top_10_categorical_accuracy: 0.8757 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 21.0012 - regularization_loss: 0.0000e+00 - total_loss: 21.0012
# Epoch 62/100
# 11/11 [==============================] - 3s 242ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3969 - factorized_top_k/top_10_categorical_accuracy: 0.8741 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 20.5084 - regularization_loss: 0.0000e+00 - total_loss: 20.5084
# Epoch 63/100
# 11/11 [==============================] - 2s 164ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3977 - factorized_top_k/top_10_categorical_accuracy: 0.8749 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 20.0355 - regularization_loss: 0.0000e+00 - total_loss: 20.0355
# Epoch 64/100
# 11/11 [==============================] - 2s 161ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3985 - factorized_top_k/top_10_categorical_accuracy: 0.8726 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 19.5816 - regularization_loss: 0.0000e+00 - total_loss: 19.5816
# Epoch 65/100
# 11/11 [==============================] - 2s 175ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3985 - factorized_top_k/top_10_categorical_accuracy: 0.8703 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 19.1455 - regularization_loss: 0.0000e+00 - total_loss: 19.1455
# Epoch 66/100
# 11/11 [==============================] - 3s 271ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3992 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 18.7263 - regularization_loss: 0.0000e+00 - total_loss: 18.7263
# Epoch 67/100
# 11/11 [==============================] - 2s 168ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3969 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 18.3231 - regularization_loss: 0.0000e+00 - total_loss: 18.3231
# Epoch 68/100
# 11/11 [==============================] - 2s 163ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3969 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 17.9351 - regularization_loss: 0.0000e+00 - total_loss: 17.9351
# Epoch 69/100
# 11/11 [==============================] - 2s 165ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3938 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 17.5614 - regularization_loss: 0.0000e+00 - total_loss: 17.5614
# Epoch 70/100
# 11/11 [==============================] - 2s 161ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3961 - factorized_top_k/top_10_categorical_accuracy: 0.8718 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 17.2013 - regularization_loss: 0.0000e+00 - total_loss: 17.2013
# Epoch 71/100
# 11/11 [==============================] - 2s 195ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3923 - factorized_top_k/top_10_categorical_accuracy: 0.8726 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 16.8543 - regularization_loss: 0.0000e+00 - total_loss: 16.8543
# Epoch 72/100
# 11/11 [==============================] - 2s 223ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3931 - factorized_top_k/top_10_categorical_accuracy: 0.8718 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 16.5195 - regularization_loss: 0.0000e+00 - total_loss: 16.5195
# Epoch 73/100
# 11/11 [==============================] - 2s 164ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3931 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 0.9992 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 16.1965 - regularization_loss: 0.0000e+00 - total_loss: 16.1965
# Epoch 74/100
# 11/11 [==============================] - 2s 167ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3931 - factorized_top_k/top_10_categorical_accuracy: 0.8741 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 15.8846 - regularization_loss: 0.0000e+00 - total_loss: 15.8846
# Epoch 75/100
# 11/11 [==============================] - 2s 164ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3923 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 15.5834 - regularization_loss: 0.0000e+00 - total_loss: 15.5834
# Epoch 76/100
# 11/11 [==============================] - 2s 185ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3907 - factorized_top_k/top_10_categorical_accuracy: 0.8734 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 15.2923 - regularization_loss: 0.0000e+00 - total_loss: 15.2923
# Epoch 77/100
# 11/11 [==============================] - 3s 268ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3915 - factorized_top_k/top_10_categorical_accuracy: 0.8710 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 15.0109 - regularization_loss: 0.0000e+00 - total_loss: 15.0109
# Epoch 78/100
# 11/11 [==============================] - 2s 169ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3884 - factorized_top_k/top_10_categorical_accuracy: 0.8710 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 14.7387 - regularization_loss: 0.0000e+00 - total_loss: 14.7387
# Epoch 79/100
# 11/11 [==============================] - 2s 168ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3884 - factorized_top_k/top_10_categorical_accuracy: 0.8710 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 14.4753 - regularization_loss: 0.0000e+00 - total_loss: 14.4753
# Epoch 80/100
# 11/11 [==============================] - 2s 162ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3869 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 14.2204 - regularization_loss: 0.0000e+00 - total_loss: 14.2204
# Epoch 81/100
# 11/11 [==============================] - 2s 183ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3876 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 13.9736 - regularization_loss: 0.0000e+00 - total_loss: 13.9736
# Epoch 82/100
# 11/11 [==============================] - 3s 235ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3876 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 13.7345 - regularization_loss: 0.0000e+00 - total_loss: 13.7345
# Epoch 83/100
# 11/11 [==============================] - 2s 172ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 13.5028 - regularization_loss: 0.0000e+00 - total_loss: 13.5028
# Epoch 84/100
# 11/11 [==============================] - 2s 172ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8672 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 13.2783 - regularization_loss: 0.0000e+00 - total_loss: 13.2783
# Epoch 85/100
# 11/11 [==============================] - 2s 172ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3853 - factorized_top_k/top_10_categorical_accuracy: 0.8672 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 13.0606 - regularization_loss: 0.0000e+00 - total_loss: 13.0606
# Epoch 86/100
# 11/11 [==============================] - 3s 239ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3846 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 12.8495 - regularization_loss: 0.0000e+00 - total_loss: 12.8495
# Epoch 87/100
# 11/11 [==============================] - 2s 169ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3869 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 12.6448 - regularization_loss: 0.0000e+00 - total_loss: 12.6448
# Epoch 88/100
# 11/11 [==============================] - 2s 168ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 12.4461 - regularization_loss: 0.0000e+00 - total_loss: 12.4461
# Epoch 89/100
# 11/11 [==============================] - 2s 165ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8703 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 12.2534 - regularization_loss: 0.0000e+00 - total_loss: 12.2534
# Epoch 90/100
# 11/11 [==============================] - 2s 164ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8710 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 12.0664 - regularization_loss: 0.0000e+00 - total_loss: 12.0664
# Epoch 91/100
# 11/11 [==============================] - 3s 250ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8718 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.8848 - regularization_loss: 0.0000e+00 - total_loss: 11.8848
# Epoch 92/100
# 11/11 [==============================] - 2s 174ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3861 - factorized_top_k/top_10_categorical_accuracy: 0.8718 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.7086 - regularization_loss: 0.0000e+00 - total_loss: 11.7086
# Epoch 93/100
# 11/11 [==============================] - 2s 163ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3838 - factorized_top_k/top_10_categorical_accuracy: 0.8687 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.5376 - regularization_loss: 0.0000e+00 - total_loss: 11.5376
# Epoch 94/100
# 11/11 [==============================] - 2s 166ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3830 - factorized_top_k/top_10_categorical_accuracy: 0.8695 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.3715 - regularization_loss: 0.0000e+00 - total_loss: 11.3715
# Epoch 95/100
# 11/11 [==============================] - 3s 251ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3830 - factorized_top_k/top_10_categorical_accuracy: 0.8703 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.2102 - regularization_loss: 0.0000e+00 - total_loss: 11.2102
# Epoch 96/100
# 11/11 [==============================] - 3s 277ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3830 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 11.0537 - regularization_loss: 0.0000e+00 - total_loss: 11.0537
# Epoch 97/100
# 11/11 [==============================] - 4s 317ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3807 - factorized_top_k/top_10_categorical_accuracy: 0.8664 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 10.9016 - regularization_loss: 0.0000e+00 - total_loss: 10.9016
# Epoch 98/100
# 11/11 [==============================] - 5s 448ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3768 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 10.7539 - regularization_loss: 0.0000e+00 - total_loss: 10.7539
# Epoch 99/100
# 11/11 [==============================] - 2s 166ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3753 - factorized_top_k/top_10_categorical_accuracy: 0.8680 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 10.6104 - regularization_loss: 0.0000e+00 - total_loss: 10.6104
# Epoch 100/100
# 11/11 [==============================] - 2s 165ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0031 - factorized_top_k/top_5_categorical_accuracy: 0.3753 - factorized_top_k/top_10_categorical_accuracy: 0.8672 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 10.4710 - regularization_loss: 0.0000e+00 - total_loss: 10.4710
# Top recommendations:
# Recommended recipe ID: 546
# Title: Oreo Cheesecake Recipe
# Ingredients: breadcrumbs, butter, cheese, container sour cream, cornstarch, eggs, lemon juice, milk, oreo cookies, sugar, vanilla extract, whipped cream
# Ingredient Groups: IngredientGroup(ingredients=['2 cups chocolate graham cracker crumbs', '2 tablespoons sugar', '6 tablespoons butter (melted)', '2 (8 oz.) packages cream cheese', '1/4 cup sweetened condensed milk', '1/4 cup sugar', '1/4 cup cornstarch', '2 teaspoons vanilla extract', '2 eggs', '2 teaspoons lemon juice', '1 (8 oz.) container sour cream', 'Whipped Cream', '6 Oreo cookies'], purpose=None)\Calories: 633.0
#
# Recommended recipe ID: 1011
# Title: Spicy Pulled Pork Stuffed Sweet Potatoes Recipe
# Ingredients: bbq sauce (homemade or store-bought, oil, plus more for serving if desired), pork butt, salt, sweet potatoes
# Ingredient Groups: IngredientGroup(ingredients=['1 (3-pound) pork butt (bone-in)', '1 cup BBQ sauce (homemade or store-bought, plus more for serving if desired)', '8 medium sweet potatoes (scrubbed)', 'olive oil', 'kosher salt'], purpose=None)\Calories: 657.0
#
# Recommended recipe ID: 838
# Title: Philly Cheesesteak Recipe
# Ingredients: cheese, hoagie rolls, oil, onion, or a mixture), peppers (green, poblano, red, seasoning, sirloin steak
# Ingredient Groups: IngredientGroup(ingredients=['2 pounds sirloin steak (thinly sliced)', '1 tablespoon Stone House Seasoning', '2 tablespoons olive oil (divided)', '1 medium sweet onion (thinly sliced)', '2 medium peppers (green, red, poblano, or a mixture) (thinly sliced)', '4 hoagie rolls', '8 slices Provolone cheese'], purpose=None)\Calories: 706.0
#
# Recommended recipe ID: 420
# Title: Chocolate Cake Hearts Recipe
# Ingredients: chocolate, raspberry sauce
# Ingredient Groups: IngredientGroup(ingredients=['1 chocolate cake recipe', '1 chocolate ganache recipe', 'raspberry sauce (optional)'], purpose=None)\Calories: 612.0
